# %%
#  # 1. Indentation Error
# -Causes due to incorrect indentation, usually due to inconsistent use of spaces or tabs
# sol: Ensure consistent indentation using four spaces. Corrected code:

    
    


# # 2. Type Error
# - *Causes due to attempting to perform an operation on a value of the wrong data type.



# num = "five"
# result = num + 5



    
# *   Solution: Ensure variables have the correct data type before performing operations. Corrected code:

    
#     num = 5
#     result = num + 5


# # 3. Name Error
# Causes due to Using a variable or function name that hasn't been defined.


# print(greeting)

# `
# *   **Solution:** Define the variable or function before using it. 

    

# # 4. Value Error
# Causes due to  Passing an incorrect value to a function or operation.

# int("hello")

# *Solution:Ensure the value passed is valid for the operation. Corrected code:

    
#     num = int("5")
#     print(num)


# # 5. Key Error
# - *Cause:* Attempting to access a key that doesn't exist in a dictionary.
# - *Example:*


# person = {"name": "John", "age": 30}
# print(person["city"])

# Solution : Ensure the key exists in the dictionary before accessing it. Use the `get()` method to provide a default value if the key doesn't exist. Corrected code:

    
#     person = {"name": "John", "age": 30}
#     city = person.get("city", "Unknown")
#     print(city)
